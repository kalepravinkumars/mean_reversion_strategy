# %% [markdown]
# <a href="https://colab.research.google.com/github/kalepravinkumars/mean_reversion_strategy/blob/main/mean_reversion_strategy_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

nifty50_symbols = [
    'RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'INFY.NS', 'ICICIBANK.NS',
    'KOTAKBANK.NS', 'HDFC.NS', 'ITC.NS', 'LT.NS', 'SBIN.NS', 'ASIANPAINT.NS', 'AXISBANK.NS',
    'MARUTI.NS', 'HCLTECH.NS', 'BAJFINANCE.NS', 'TECHM.NS', 'BAJAJFINSV.NS', 'ONGC.NS',
    'TITAN.NS', 'NESTLEIND.NS', 'HEROMOTOCO.NS', 'WIPRO.NS', 'COALINDIA.NS', 'POWERGRID.NS',
    'INDUSINDBK.NS', 'ULTRACEMCO.NS', 'SUNPHARMA.NS', 'BHARTIARTL.NS', 'JSWSTEEL.NS',
    'M&M.NS', 'DRREDDY.NS', 'CIPLA.NS', 'BRITANNIA.NS', 'GRASIM.NS', 'TATASTEEL.NS',
    'EICHERMOT.NS', 'DIVISLAB.NS', 'ADANIPORTS.NS', 'SHREECEM.NS', 'NTPC.NS', 'SBILIFE.NS',
    'BAJAJ-AUTO.NS', 'HINDALCO.NS', 'IOC.NS', 'UPL.NS', 'VEDL.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS',
    'JSWENERGY.NS', 'TATAMOTORS.NS', 'IOC.BO', 'ONGC.BO', 'COALINDIA.BO'
]


def fetch_stock_data(symbol, start_date, end_date):
    # Fetch historical stock data from Yahoo Finance
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

    return stock_data

def mean_reversion_strategy(stock_data,sigma):
    # Calculate the mean and standard deviation
    stock_data['Mean'] = stock_data['Close'].rolling(window=15).mean()
    stock_data['Std'] = stock_data['Close'].rolling(window=15).std()

    # Define the upper and lower bands
    stock_data['Upper Band'] = stock_data['Mean'] + (sigma * stock_data['Std'])
    stock_data['Lower Band'] = stock_data['Mean'] - (sigma * stock_data['Std'])

    # Generate trading signals
    stock_data['Signal'] = 0
    stock_data.loc[stock_data['Close'] > stock_data['Upper Band'], 'Signal'] = -1
    stock_data.loc[stock_data['Close'] < stock_data['Lower Band'], 'Signal'] = 1

    # Calculate profit/loss
    stock_data['Buy Price'] = stock_data['Close'].shift(1)
    stock_data['Profit/Loss'] = (stock_data['Close'] - stock_data['Buy Price']) * stock_data['Signal']

    return stock_data

# %%
# Set the date range for fetching historical data
start_date = '2020-01-01'
end_date = '2022-12-31'

for i in nifty50_symbols:
  symbol = i
  stock_data = fetch_stock_data(symbol, start_date, end_date)

  # Perform mean reversion strategy
  strategy_data = mean_reversion_strategy(stock_data,1.2)

  # Display the trading signal history and profit/loss
  #print(strategy_data[['Close', 'Upper Band', 'Lower Band', 'Signal', 'Profit/Loss']].head())

  #print(strategy_data.describe())
  if strategy_data['Profit/Loss'].min()-strategy_data['Profit/Loss'].max() >0:
    print(i)
    print('maximum profit: ', strategy_data['Profit/Loss'].max())
    print('minimum profit: ',strategy_data['Profit/Loss'].min())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Set the date range for fetching historical data
start_date = '2021-01-01'
end_date = '2022-12-31'


for i in nifty50_symbols:
  symbol = i
  stock_data = fetch_stock_data(symbol, start_date, end_date)
  sig=0.5
  for j in range(1,10):

    # Perform mean reversion strategy
    strategy_data = mean_reversion_strategy(stock_data,j)
    # Display the trading signal history and profit/loss
    #print(strategy_data[['Close', 'Upper Band', 'Lower Band', 'Signal', 'Profit/Loss']].head())
    #print(strategy_data.describe())
    if strategy_data['Profit/Loss'].min()-strategy_data['Profit/Loss'].max() >0:
      print(j)
      print(i)
      print('maximum profit: ', strategy_data['Profit/Loss'].max())
      print('minimum profit: ',strategy_data['Profit/Loss'].min())
    sig +=0.5
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def mean_reversion_strategy_1(stock_data,rollavg,sigma):
    # Calculate the mean and standard deviation
    stock_data['Mean'] = stock_data['Close'].rolling(window=rollavg).mean()
    stock_data['Std'] = stock_data['Close'].rolling(window=rollavg).std()

    # Define the upper and lower bands
    stock_data['Upper Band'] = stock_data['Mean'] + (sigma * stock_data['Std'])
    stock_data['Lower Band'] = stock_data['Mean'] - (sigma * stock_data['Std'])

    # Generate trading signals
    stock_data['Signal'] = 0
    stock_data.loc[(stock_data['Close'] > stock_data['Upper Band']) & (stock_data['Close'] > stock_data['Mean']), 'Signal'] = -1
    stock_data.loc[stock_data['Close'] < stock_data['Lower Band'], 'Signal'] = 1

    # Calculate profit/loss
    stock_data['Buy Price'] = stock_data['Close'].shift(1)
    stock_data['Profit/Loss'] = (stock_data['Close'] - stock_data['Buy Price']) * stock_data['Signal']

    return stock_data

# %%
# Set the date range for fetching historical data
start_date = '2010-01-01'
end_date = '2022-12-31'


for i in nifty50_symbols:
  symbol = i
  stock_data = fetch_stock_data(symbol, start_date, end_date)
  for roll in range(1,30):
    sig=0.5
    for j in range(1,4):
      # Perform mean reversion strategy
      strategy_data = mean_reversion_strategy_1(stock_data,roll,j)
      # Display the trading signal history and profit/loss
      #print(strategy_data[['Close', 'Upper Band', 'Lower Band', 'Signal', 'Profit/Loss']].head())
      #print(strategy_data.describe())
      if strategy_data['Profit/Loss'].sum() >-100:
        print(j)
        print(i)
        print('maximum profit: ', strategy_data['Profit/Loss'].max())
        print('minimum profit: ',strategy_data['Profit/Loss'].min())
      #print('maximum profit: ', strategy_data['Profit/Loss'].max())
      #print('minimum profit: ',strategy_data['Profit/Loss'].min())
      #print('Total profit: ', strategy_data['Profit/Loss'].sum())
      sig +=0.5
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -21.0999755859375
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# RELIANCE.NS
# maximum profit:  -0.0
# minimum profit:  -23.25457763671875
# [*********************100%***********************]  1 of 1 completed
# 1
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TCS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCBANK.NS
# maximum profit:  0.0
# minimum profit:  -17.925018310546875
# [*********************100%***********************]  1 of 1 completed
# 1
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# HINDUNILVR.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# INFY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  -39.1500244140625
# 3
# ICICIBANK.NS
# maximum profit:  0.0
# minimum profit:  -39.1500244140625
# [*********************100%***********************]  1 of 1 completed
# 1
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# KOTAKBANK.NS
# maximum profit:  0.0
# minimum profit:  -51.85003662109375
# [*********************100%***********************]  1 of 1 completed
# 1
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  -40.600006103515625
# 3
# ITC.NS
# maximum profit:  0.0
# minimum profit:  -27.54998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# LT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  -70.44999694824219
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  -70.44999694824219
# 3
# SBIN.NS
# maximum profit:  0.0
# minimum profit:  -70.44999694824219
# [*********************100%***********************]  1 of 1 completed
# 1
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ASIANPAINT.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# AXISBANK.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# MARUTI.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HCLTECH.NS
# maximum profit:  0.0
# minimum profit:  -50.29998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# BAJFINANCE.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TECHM.NS
# maximum profit:  0.0
# minimum profit:  -48.25
# [*********************100%***********************]  1 of 1 completed
# 1
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJFINSV.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  -12.341659545898438
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  -25.349990844726562
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  -25.349990844726562
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  -25.349990844726562
# 3
# ONGC.NS
# maximum profit:  0.0
# minimum profit:  -25.349990844726562
# [*********************100%***********************]  1 of 1 completed
# 1
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TITAN.NS
# maximum profit:  0.0
# minimum profit:  -80.0999755859375
# [*********************100%***********************]  1 of 1 completed
# 1
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# NESTLEIND.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HEROMOTOCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  -37.75
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  -37.75
# 3
# WIPRO.NS
# maximum profit:  0.0
# minimum profit:  -37.75
# [*********************100%***********************]  1 of 1 completed
# 1
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -25.0
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -35.050018310546875
# 3
# COALINDIA.NS
# maximum profit:  -0.0
# minimum profit:  -35.050018310546875
# [*********************100%***********************]  1 of 1 completed
# 1
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -7.6125030517578125
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -3.5250015258789062
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -11.100006103515625
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -11.100006103515625
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -11.100006103515625
# 3
# POWERGRID.NS
# maximum profit:  0.0
# minimum profit:  -11.100006103515625
# [*********************100%***********************]  1 of 1 completed
# 1
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# INDUSINDBK.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ULTRACEMCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  -25.25
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  -70.95001220703125
# 3
# SUNPHARMA.NS
# maximum profit:  0.0
# minimum profit:  -70.95001220703125
# [*********************100%***********************]  1 of 1 completed
# 1
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BHARTIARTL.NS
# maximum profit:  0.0
# minimum profit:  -20.10809326171875
# [*********************100%***********************]  1 of 1 completed
# 1
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  -16.4000244140625
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  -49.0999755859375
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  -49.0999755859375
# 3
# JSWSTEEL.NS
# maximum profit:  0.0
# minimum profit:  -49.0999755859375
# [*********************100%***********************]  1 of 1 completed
# 1
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  -24.1500244140625
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  -24.1500244140625
# 3
# M&M.NS
# maximum profit:  0.0
# minimum profit:  -46.25
# [*********************100%***********************]  1 of 1 completed
# 1
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# DRREDDY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -32.45001220703125
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -36.29998779296875
# 3
# CIPLA.NS
# maximum profit:  -0.0
# minimum profit:  -36.29998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BRITANNIA.NS
# maximum profit:  0.0
# minimum profit:  0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# GRASIM.NS
# maximum profit:  0.0
# minimum profit:  -41.75
# [*********************100%***********************]  1 of 1 completed
# 1
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# 3
# TATASTEEL.NS
# maximum profit:  0.0
# minimum profit:  -13.279998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# EICHERMOT.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# DIVISLAB.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# [*********************100%***********************]  1 of 1 completed
# 1
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  -13.699981689453125
# 3
# ADANIPORTS.NS
# maximum profit:  0.0
# minimum profit:  -53.79998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# SHREECEM.NS
# ...
# 2
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# BAJAJ-AUTO.NS
# maximum profit:  0.0
# minimum profit:  -58.1500244140625
# [*********************100%***********************]  1 of 1 completed
# 1
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  -31.04998779296875
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  -13.650009155273438
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  -14.0
# 3
# HINDALCO.NS
# maximum profit:  0.0
# minimum profit:  -41.800018310546875
# [*********************100%***********************]  1 of 1 completed
# 1
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.NS
# maximum profit:  0.0
# minimum profit:  -5.649993896484375
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  -14.833335876464844
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  -14.833335876464844
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  -14.833335876464844
# 3
# IOC.NS
# maximum profit:  0.0
# minimum profit:  -14.833335876464844
# [*********************100%***********************]  1 of 1 completed
# 1
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  -39.5999755859375
# 3
# UPL.NS
# maximum profit:  0.0
# minimum profit:  -36.75
# [*********************100%***********************]  1 of 1 completed
# 1
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  -35.20001220703125
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  -35.20001220703125
# 3
# VEDL.NS
# maximum profit:  0.0
# minimum profit:  -35.20001220703125
# [*********************100%***********************]  1 of 1 completed
# 1
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  -38.04998779296875
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  -33.9000244140625
# 3
# HDFCLIFE.NS
# maximum profit:  0.0
# minimum profit:  -33.9000244140625
# [*********************100%***********************]  1 of 1 completed
# 1
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  -16.600006103515625
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# HINDPETRO.NS
# maximum profit:  0.0
# minimum profit:  -52.04998779296875
# [*********************100%***********************]  1 of 1 completed
# 1
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -7.9499969482421875
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# 3
# JSWENERGY.NS
# maximum profit:  0.0
# minimum profit:  -11.899993896484375
# [*********************100%***********************]  1 of 1 completed
# 1
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -18.600006103515625
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# TATAMOTORS.NS
# maximum profit:  -0.0
# minimum profit:  -32.15000915527344
# [*********************100%***********************]  1 of 1 completed
# 1
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# IOC.BO
# maximum profit:  0.0
# minimum profit:  -5.666656494140625
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  -15.200004577636719
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  -15.200004577636719
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  -15.200004577636719
# 3
# IOC.BO
# maximum profit:  0.0
# minimum profit:  -15.200004577636719
# [*********************100%***********************]  1 of 1 completed
# 1
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 1
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 2
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  0.0
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# 3
# ONGC.BO
# maximum profit:  0.0
# minimum profit:  -27.850006103515625
# [*********************100%***********************]  1 of 1 completed
# 1
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 1
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 2
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -25.149993896484375
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -0.0
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -25.149993896484375
# 3
# COALINDIA.BO
# maximum profit:  -0.0
# minimum profit:  -36.25

# %%
nifty50_symbols = [
    'RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'INFY.NS', 'ICICIBANK.NS',
    'KOTAKBANK.NS', 'HDFC.NS', 'ITC.NS', 'LT.NS', 'SBIN.NS', 'ASIANPAINT.NS', 'AXISBANK.NS',
    'MARUTI.NS', 'HCLTECH.NS', 'BAJFINANCE.NS', 'TECHM.NS', 'BAJAJFINSV.NS', 'ONGC.NS',
    'TITAN.NS', 'NESTLEIND.NS', 'HEROMOTOCO.NS', 'WIPRO.NS', 'COALINDIA.NS', 'POWERGRID.NS',
    'INDUSINDBK.NS', 'ULTRACEMCO.NS', 'SUNPHARMA.NS', 'BHARTIARTL.NS', 'JSWSTEEL.NS',
    'M&M.NS', 'DRREDDY.NS', 'CIPLA.NS', 'BRITANNIA.NS', 'GRASIM.NS', 'TATASTEEL.NS',
    'EICHERMOT.NS', 'DIVISLAB.NS', 'ADANIPORTS.NS', 'SHREECEM.NS', 'NTPC.NS', 'SBILIFE.NS',
    'BAJAJ-AUTO.NS', 'HINDALCO.NS', 'IOC.NS', 'UPL.NS', 'VEDL.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS',
    'JSWENERGY.NS', 'TATAMOTORS.NS'
]

banknifty_symbols = [
    'HDFCBANK.NS', 'ICICIBANK.NS', 'AXISBANK.NS', 'SBIN.NS', 'KOTAKBANK.NS', 'INDUSINDBK.NS',
    'BANKBARODA.NS', 'PNB.NS', 'IDFCFIRSTB.NS', 'FEDERALBNK.NS', 'BANDHANBNK.NS', 'RBLBANK.NS',
    'SBICARD.NS', 'IDBI.NS', 'CANBK.NS', 'SYNDIBANK.NS', 'UCOBANK.NS', 'SOUTHBANK.NS',
    'UNIONBANK.NS', 'CENTRALBK.NS', 'J&KBANK.NS', 'KARURVYSYA.NS', 'FEDERALBNK.NS', 'BANKINDIA.NS',
    'VIJAYABANK.NS', 'INDIANB.NS', 'IOB.NS', 'PNBHOUSING.NS', 'DBS.NS', 'DCBBANK.NS', 'AUROPHARMA.NS'
]

# Combine and get unique symbols
combined_symbols = list(set(nifty50_symbols + banknifty_symbols))




# Set the date range for fetching historical data
start_date = '2010-01-01'
end_date = '2022-12-31'
profit=[]


for i in combined_symbols:
  symbol = i
  stock_data = fetch_stock_data(symbol, start_date, end_date)
  for roll in range(1,360):
    sig=0.5
    for j in range(1,6):
      # Perform mean reversion strategy
      strategy_data = mean_reversion_strategy_1(stock_data,roll,j)
      # Display the trading signal history and profit/loss
      #print(strategy_data[['Close', 'Upper Band', 'Lower Band', 'Signal', 'Profit/Loss']].head())
      #print(strategy_data.describe())
      if strategy_data['Profit/Loss'].sum() >0:
        print('sigma',sig)
        print('rolling_window',roll)
        print('stock name',i)
        print('maximum profit: ', strategy_data['Profit/Loss'].max())
        print('minimum profit: ',strategy_data['Profit/Loss'].min())
        print('Total profit: ', strategy_data['Profit/Loss'].sum())
      #print('maximum profit: ', strategy_data['Profit/Loss'].max())
      #print('minimum profit: ',strategy_data['Profit/Loss'].min())
      #print('Total profit: ', strategy_data['Profit/Loss'].sum())

      sig +=0.5
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DBS.NS: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SYNDIBANK.NS: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VIJAYABANK.NS: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 2.0
# rolling_window 248
# stock name SBILIFE.NS
# maximum profit:  20.70001220703125
# minimum profit:  -0.0
# Total profit:  30.449981689453125
# sigma 2.5
# rolling_window 248
# stock name SBILIFE.NS
# maximum profit:  9.749969482421875
# minimum profit:  -0.0
# Total profit:  9.749969482421875
# sigma 2.0
# rolling_window 249
# stock name SBILIFE.NS
# maximum profit:  20.70001220703125
# minimum profit:  -0.0
# Total profit:  20.70001220703125
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
pip install nsetools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nsetools
#   Downloading nsetools-1.0.11-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from nsetools) (1.16.0)
# Collecting dateutils (from nsetools)
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateutils->nsetools) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateutils->nsetools) (2022.7.1)
# Installing collected packages: dateutils, nsetools
# Successfully installed dateutils-0.6.12 nsetools-1.0.11

# %%
from nsetools import Nse

def get_nifty500_symbols():
    nse = Nse()
    all_stock_codes = nse.get_stock_codes()

    nifty500_codes = [code for code, name in all_stock_codes.items() if 'NIFTY 500' in name]
    symbols = [code for code in nifty500_codes if code.isalpha()]

    return symbols

# Get the Nifty 500 symbols
nifty500_symbols = get_nifty500_symbols()
print(nifty500_symbols)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-0f97c4e68ebd> in <cell line: 13>()
#      11
#      12 # Get the Nifty 500 symbols
# ---> 13 nifty500_symbols = get_nifty500_symbols()
#      14 print(nifty500_symbols)
#
# <ipython-input-18-0f97c4e68ebd> in get_nifty500_symbols()
#       3 def get_nifty500_symbols():
#       4     nse = Nse()
# ----> 5     all_stock_codes = nse.get_stock_codes()
#       6
#       7     nifty500_codes = [code for code, name in all_stock_codes.items() if 'NIFTY 500' in name]
#
# /usr/local/lib/python3.10/dist-packages/nsetools/nse.py in get_stock_codes(self, cached, as_json)
#     115         if cached is not True or self.__CODECACHE__ is None:
#     116             # raises HTTPError and URLError
# --> 117             res = self.opener.open(req)
#     118             if res is not None:
#     119                 # for py3 compat covert byte file like object to
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     736             if (visited.get(newurl, 0) >= self.max_repeats or
#     737                 len(visited) >= self.max_redirections):
# --> 738                 raise HTTPError(req.full_url, code,
#     739                                 self.inf_msg + msg, headers, fp)
#     740         else:
#
# HTTPError: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently

# %% [markdown]
# <a href="https://colab.research.google.com/github/kalepravinkumars/mean_reversion_strategy/blob/main/mean_reversion_strategy_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

# %%
def fetch_stock_data(symbol, start_date, end_date):
    # Fetch historical stock data from Yahoo Finance
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

    return stock_data

# %%
def mean_reversion_strategy(stock_data,rollavg,sigma):
    # Calculate the mean and standard deviation
    stock_data['Mean'] = stock_data['Close'].rolling(window=rollavg).mean()
    stock_data['Std'] = stock_data['Close'].rolling(window=rollavg).std()

    # Define the upper and lower bands
    stock_data['Upper Band'] = stock_data['Mean'] + (sigma * stock_data['Std'])
    stock_data['Lower Band'] = stock_data['Mean'] - (sigma * stock_data['Std'])

    # Generate trading signals
    stock_data['Signal'] = 0
    stock_data.loc[(stock_data['Close'] > stock_data['Upper Band']), 'Signal'] = -1
    stock_data.loc[stock_data['Close'] < stock_data['Lower Band'], 'Signal'] = 1

    # Calculate profit/loss
    stock_data['Buy Price'] = stock_data['Close'].shift(1)
    stock_data['Profit/Loss'] = (stock_data['Close'] - stock_data['Buy Price']) * stock_data['Signal']

    return stock_data

# %%
def mean_reversion_strategy_1(stock_data,rollavg,sigma):
    # Calculate the mean and standard deviation
    stock_data['Mean'] = stock_data['Close'].rolling(window=rollavg).mean()
    stock_data['Std'] = stock_data['Close'].rolling(window=rollavg).std()

    # Define the upper and lower bands
    stock_data['Upper Band'] = stock_data['Mean'] + (sigma * stock_data['Std'])
    stock_data['Lower Band'] = stock_data['Mean'] - (sigma * stock_data['Std'])

    # Generate trading signals
    stock_data['Signal'] = 0
    stock_data.loc[(stock_data['Close'] > stock_data['Upper Band']) & (stock_data['Close'] > stock_data['Mean']), 'Signal'] = -1
    stock_data.loc[stock_data['Close'] < stock_data['Lower Band'], 'Signal'] = 1

    # Calculate profit/loss
    stock_data['Buy Price'] = stock_data['Close'].shift(1)
    stock_data['Profit/Loss'] = (stock_data['Close'] - stock_data['Buy Price']) * stock_data['Signal']

    return stock_data

# %%
nifty50_symbols = [
    'RELIANCE.NS', 'TCS.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'INFY.NS', 'ICICIBANK.NS',
    'KOTAKBANK.NS', 'HDFC.NS', 'ITC.NS', 'LT.NS', 'SBIN.NS', 'ASIANPAINT.NS', 'AXISBANK.NS',
    'MARUTI.NS', 'HCLTECH.NS', 'BAJFINANCE.NS', 'TECHM.NS', 'BAJAJFINSV.NS', 'ONGC.NS',
    'TITAN.NS', 'NESTLEIND.NS', 'HEROMOTOCO.NS', 'WIPRO.NS', 'COALINDIA.NS', 'POWERGRID.NS',
    'INDUSINDBK.NS', 'ULTRACEMCO.NS', 'SUNPHARMA.NS', 'BHARTIARTL.NS', 'JSWSTEEL.NS',
    'M&M.NS', 'DRREDDY.NS', 'CIPLA.NS', 'BRITANNIA.NS', 'GRASIM.NS', 'TATASTEEL.NS',
    'EICHERMOT.NS', 'DIVISLAB.NS', 'ADANIPORTS.NS', 'SHREECEM.NS', 'NTPC.NS', 'SBILIFE.NS',
    'BAJAJ-AUTO.NS', 'HINDALCO.NS', 'IOC.NS', 'UPL.NS', 'VEDL.NS', 'HDFCLIFE.NS', 'HINDPETRO.NS',
    'JSWENERGY.NS', 'TATAMOTORS.NS'
]

banknifty_symbols = [
    'HDFCBANK.NS', 'ICICIBANK.NS', 'AXISBANK.NS', 'SBIN.NS', 'KOTAKBANK.NS', 'INDUSINDBK.NS',
    'BANKBARODA.NS', 'PNB.NS', 'IDFCFIRSTB.NS', 'FEDERALBNK.NS', 'BANDHANBNK.NS', 'RBLBANK.NS',
    'SBICARD.NS', 'IDBI.NS', 'CANBK.NS', 'SYNDIBANK.NS', 'UCOBANK.NS', 'SOUTHBANK.NS',
    'UNIONBANK.NS', 'CENTRALBK.NS', 'J&KBANK.NS', 'KARURVYSYA.NS', 'FEDERALBNK.NS', 'BANKINDIA.NS',
    'VIJAYABANK.NS', 'INDIANB.NS', 'IOB.NS', 'PNBHOUSING.NS', 'DBS.NS', 'DCBBANK.NS', 'AUROPHARMA.NS'
]

# Combine and get unique symbols
combined_symbols = list(set(nifty50_symbols + banknifty_symbols))




# Set the date range for fetching historical data
start_date = '2020-01-01'
end_date = '2022-12-31'
profit=[]


for i in combined_symbols:
  symbol = i
  stock_data = fetch_stock_data(symbol, start_date, end_date)
  for roll in range(1,360):
    sig=0.5
    for j in range(1,6):
      # Perform mean reversion strategy
      strategy_data = mean_reversion_strategy_1(stock_data,roll,j)
      # Display the trading signal history and profit/loss
      if strategy_data['Profit/Loss'].sum() >0:
        print('sigma',sig)
        print('rolling_window',roll)
        print('stock name',i)
        print('maximum profit: ', strategy_data['Profit/Loss'].max())
        print('minimum profit: ',strategy_data['Profit/Loss'].min())
        print('Total profit: ', strategy_data['Profit/Loss'].sum())
        print('Total Trade: ', len(strategy_data['Profit/Loss']))
        print('#################################################')
      #print('maximum profit: ', strategy_data['Profit/Loss'].max())
      #print('minimum profit: ',strategy_data['Profit/Loss'].min())
      #print('Total profit: ', strategy_data['Profit/Loss'].sum())

      sig +=0.5
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.5
# rolling_window 286
# stock name POWERGRID.NS
# maximum profit:  3.225006103515625
# minimum profit:  -0.0
# Total profit:  3.225006103515625
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# sigma 1.0
# rolling_window 354
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  17.64996337890625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 355
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  20.29998779296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 356
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  16.29998779296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 357
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  30.54998779296875
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 357
# stock name UPL.NS
# maximum profit:  8.0
# minimum profit:  -3.04998779296875
# Total profit:  4.95001220703125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 358
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  33.5999755859375
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 358
# stock name UPL.NS
# maximum profit:  8.0
# minimum profit:  0.0
# Total profit:  8.0
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 359
# stock name UPL.NS
# maximum profit:  35.79998779296875
# minimum profit:  -30.29998779296875
# Total profit:  25.5999755859375
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.5
# rolling_window 196
# stock name WIPRO.NS
# maximum profit:  1.54998779296875
# minimum profit:  0.0
# Total profit:  1.54998779296875
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.5
# rolling_window 338
# stock name VEDL.NS
# maximum profit:  5.25
# minimum profit:  0.0
# Total profit:  5.25
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# sigma 1.0
# rolling_window 331
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  22.45001220703125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 332
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  13.79998779296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 333
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  19.20001220703125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 334
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  12.7000732421875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 335
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  15.00006103515625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 336
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -27.1500244140625
# Total profit:  27.10003662109375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 337
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -25.4000244140625
# Total profit:  54.25006103515625
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 337
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -1.70001220703125
# Total profit:  49.04998779296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 338
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -25.4000244140625
# Total profit:  55.9500732421875
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 338
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  0.0
# Total profit:  50.75
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 339
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  -25.4000244140625
# Total profit:  31.550048828125
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 339
# stock name JSWSTEEL.NS
# maximum profit:  26.3499755859375
# minimum profit:  0.0
# Total profit:  26.3499755859375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 340
# stock name JSWSTEEL.NS
# maximum profit:  19.699951171875
# minimum profit:  -25.4000244140625
# Total profit:  5.2000732421875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 341
# stock name JSWSTEEL.NS
# maximum profit:  19.699951171875
# minimum profit:  -25.4000244140625
# Total profit:  4.4000244140625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 342
# stock name JSWSTEEL.NS
# maximum profit:  19.699951171875
# minimum profit:  -25.4000244140625
# Total profit:  4.50006103515625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 343
# stock name JSWSTEEL.NS
# maximum profit:  19.699951171875
# minimum profit:  -25.4000244140625
# Total profit:  7.550048828125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 354
# stock name JSWSTEEL.NS
# maximum profit:  25.75
# minimum profit:  -25.4000244140625
# Total profit:  19.10003662109375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 355
# stock name JSWSTEEL.NS
# maximum profit:  25.75
# minimum profit:  -25.4000244140625
# Total profit:  24.79998779296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 356
# stock name JSWSTEEL.NS
# maximum profit:  25.75
# minimum profit:  -25.4000244140625
# Total profit:  29.60003662109375
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SYNDIBANK.NS: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VIJAYABANK.NS: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 0.5
# rolling_window 354
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -76.29998779296875
# Total profit:  47.449981689453125
# Total Trade:  738
# #################################################
# sigma 0.5
# rolling_window 355
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -76.29998779296875
# Total profit:  116.80001831054688
# Total Trade:  738
# #################################################
# sigma 1.0
# rolling_window 355
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -76.29998779296875
# Total profit:  61.4000244140625
# Total Trade:  738
# #################################################
# sigma 0.5
# rolling_window 356
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -41.95001220703125
# Total profit:  195.39999389648438
# Total Trade:  738
# #################################################
# sigma 1.0
# rolling_window 356
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -41.95001220703125
# Total profit:  137.70001220703125
# Total Trade:  738
# #################################################
# sigma 1.5
# rolling_window 356
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -41.95001220703125
# Total profit:  66.6500244140625
# Total Trade:  738
# #################################################
# sigma 2.0
# rolling_window 356
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -41.95001220703125
# Total profit:  23.70001220703125
# Total Trade:  738
# #################################################
# sigma 0.5
# rolling_window 357
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -36.050048828125
# Total profit:  237.35000610351562
# Total Trade:  738
# #################################################
# sigma 1.0
# rolling_window 357
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -36.050048828125
# Total profit:  179.6500244140625
# Total Trade:  738
# #################################################
# sigma 1.5
# rolling_window 357
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -35.70001220703125
# Total profit:  108.60003662109375
# Total Trade:  738
# #################################################
# sigma 2.0
# rolling_window 357
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -5.95001220703125
# Total profit:  65.6500244140625
# Total Trade:  738
# #################################################
# sigma 0.5
# rolling_window 358
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -36.050048828125
# Total profit:  208.89999389648438
# Total Trade:  738
# #################################################
# sigma 1.0
# rolling_window 358
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -36.050048828125
# Total profit:  151.20001220703125
# Total Trade:  738
# #################################################
# sigma 1.5
# rolling_window 358
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -35.70001220703125
# Total profit:  80.1500244140625
# Total Trade:  738
# #################################################
# sigma 2.0
# rolling_window 358
# stock name PNBHOUSING.NS
# maximum profit:  42.25
# minimum profit:  -5.95001220703125
# Total profit:  37.20001220703125
# Total Trade:  738
# #################################################
# sigma 0.5
# rolling_window 359
# stock name PNBHOUSING.NS
# maximum profit:  40.75
# minimum profit:  -36.050048828125
# Total profit:  166.64999389648438
# Total Trade:  738
# #################################################
# sigma 1.0
# rolling_window 359
# stock name PNBHOUSING.NS
# maximum profit:  40.75
# minimum profit:  -36.050048828125
# Total profit:  108.95001220703125
# Total Trade:  738
# #################################################
# sigma 1.5
# rolling_window 359
# stock name PNBHOUSING.NS
# maximum profit:  40.75
# minimum profit:  -35.70001220703125
# Total profit:  37.9000244140625
# Total Trade:  738
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.0
# rolling_window 269
# stock name BAJAJ-AUTO.NS
# maximum profit:  129.999755859375
# minimum profit:  -108.900146484375
# Total profit:  19.900146484375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 274
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  20.05029296875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 275
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  128.900146484375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 276
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  116.050048828125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 277
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  123.800048828125
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 278
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  130.000244140625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 279
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  47.449951171875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 280
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  44.099853515625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 281
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  74.449951171875
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 282
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  28.599853515625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 283
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  14.849853515625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 284
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  25.400146484375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 285
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -79.80029296875
# Total profit:  58.250244140625
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 286
# stock name BAJAJ-AUTO.NS
# maximum profit:  114.35009765625
# minimum profit:  -56.099609375
# Total profit:  87.800537109375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 354
# stock name BAJAJ-AUTO.NS
# maximum profit:  23.30029296875
# minimum profit:  -20.14990234375
# Total profit:  25.14990234375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 355
# stock name BAJAJ-AUTO.NS
# maximum profit:  23.30029296875
# minimum profit:  -20.14990234375
# Total profit:  3.4501953125
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.0
# rolling_window 314
# stock name GRASIM.NS
# maximum profit:  63.4000244140625
# minimum profit:  -51.050048828125
# Total profit:  1.8499755859375
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 356
# stock name GRASIM.NS
# maximum profit:  11.0999755859375
# minimum profit:  -2.1500244140625
# Total profit:  10.75
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 357
# stock name GRASIM.NS
# maximum profit:  11.0999755859375
# minimum profit:  -2.1500244140625
# Total profit:  8.5
# Total Trade:  747
# #################################################
# sigma 1.0
# rolling_window 358
# stock name GRASIM.NS
# maximum profit:  11.0999755859375
# minimum profit:  -0.449951171875
# Total profit:  10.6500244140625
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# sigma 1.5
# rolling_window 337
# stock name TATASTEEL.NS
# maximum profit:  5.474998474121094
# minimum profit:  -3.4000015258789062
# Total profit:  1.80999755859375
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 338
# stock name TATASTEEL.NS
# maximum profit:  5.474998474121094
# minimum profit:  -2.9150009155273438
# Total profit:  5.209999084472656
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 339
# stock name TATASTEEL.NS
# maximum profit:  5.474998474121094
# minimum profit:  -2.9150009155273438
# Total profit:  6.964996337890625
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 340
# stock name TATASTEEL.NS
# maximum profit:  4.7050018310546875
# minimum profit:  -2.9150009155273438
# Total profit:  1.4899978637695312
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 343
# stock name TATASTEEL.NS
# maximum profit:  1.5749969482421875
# minimum profit:  0.0
# Total profit:  1.5749969482421875
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# sigma 1.5
# rolling_window 295
# stock name IDFCFIRSTB.NS
# maximum profit:  1.399993896484375
# minimum profit:  -1.0999984741210938
# Total profit:  0.4499969482421875
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 296
# stock name IDFCFIRSTB.NS
# maximum profit:  1.399993896484375
# minimum profit:  -0.4499969482421875
# Total profit:  1.5499954223632812
# Total Trade:  747
# #################################################
# sigma 1.5
# rolling_window 297
# stock name IDFCFIRSTB.NS
# maximum profit:  0.5999984741210938
# minimum profit:  -0.4499969482421875
# Total profit:  0.15000152587890625
# Total Trade:  747
# #################################################
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DBS.NS: No timezone found, symbol may be delisted

# %%
strategy_data
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Mean, Std, Upper Band, Lower Band, Signal, Buy Price, Profit/Loss]
# Index: []
